# %%
import operator
from PIL import Image
from PIL import ImageDraw

# %%
imgF_4=Image.open('F_4.png')
imgF_5=Image.open('F_5.png')
imgF_6=Image.open('F_6.png')

# %%
imgF_4
imgF_4 = imgF_4.resize((224,224))

imgF_5
imgF_5 = imgF_5.resize((224,224))

imgF_6
imgF_6 = imgF_6.resize((224,224))

test_image=Image.open('./test/Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions/actinic-keratosis-5FU-28.jpg')
test_image=test_image.resize((224,224))

# %%
background = test_image
overlay = imgF_6

background = background.convert("RGBA")
overlay = overlay.convert("RGBA")

new_img = Image.blend(background, overlay, 0.4) #the third param here is the level of transparency desired
new_img
new_img = new_img.convert('RGB')
new_img.save(f'{DIR}/new_img.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_103/1027583495.py in <cell line: 1>()
# ----> 1 background = test_image
#       2 overlay = imgF_6
#       3
#       4 background = background.convert("RGBA")
#       5 overlay = overlay.convert("RGBA")
#
# NameError: name 'test_image' is not defined

# %%
test_image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import matplotlib.image

# %%
matplotlib.image.imsave('test_blend.png', new_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_103/3456462873.py in <cell line: 1>()
# ----> 1 matplotlib.image.imsave('test_blend.png', new_img)
#
# NameError: name 'new_img' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import os

# %%
pip install opencv-python-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import glob
import os
import numpy as np
import cv2

# %%
import matplotlib.image as mp_image

# %%
DIR = 'F_6Blended/test/'
classes = os.listdir(DIR)
print(f'Total classes: {len(classes)}')
# Out:
# Total classes: 23

# %%
DIR = 'F_6Blended/test/'
test_imgs = []
for _class in classes:
    
    for img in os.listdir(DIR + _class):
        test_imgs.append(f'{DIR}{_class}/{img}')

# %%
# Go to where the images are
DIR = 'F_6Blended/test/'
classes = os.listdir('F_6Blended/test/')
overlay6 = Image.open('F_6.png')

for path in test_imgs:
    background = Image.open(path)
    background = background.resize((224,224))
    background = background.convert("RGBA")
    overlay6 = overlay6.resize((224,224))
    overlay6 = overlay6.convert("RGBA")
    new_img = Image.blend(background, overlay6, 0.5) #the third param here is the level of transparency desired
    new_img = new_img.convert('RGB')
    new_img.save(path)

# %%
# Go to where the images are
DIR = 'F_6Blended/train/'
classes = os.listdir('F_6Blended/train/')
overlay5 = Image.open('F_6.png')

for path in train_imgs:
    background = Image.open(path)
    background = background.resize((224,224))
    background = background.convert("RGBA")
    overlay6 = overlay6.resize((224,224))
    overlay6 = overlay6.convert("RGBA")
    new_img = Image.blend(background, overlay6, 0.3) #the third param here is the level of transparency desired
    new_img = new_img.convert('RGB')
    new_img.save(path)

# %%
overlay4

# %%
overlay5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=78x70>

# %%
overlay6
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=82x68>

# %%
#to remove folder 
switch = True
if switch:
    # !rm rf F_6Blendedtrain
    # !cp  -r test F_6Blended

# %%
pwd
# Out:
# '/home/studio-lab-user/sagemaker-studiolab-notebooks'

# %%
##Unit Test
# background = Image.open(train_imgs[0])
# overlay = Image.open('F_4.png')
# background = background.resize((224,224))
# overlay = overlay.resize((224,224))
# background = background.convert("RGBA")
# overlay = overlay.convert("RGBA")
# new_img = Image.blend(background, overlay, 0.6) #the third param here is the level of transparency desired
# new_img = new_img.convert('RGB')
# new_img.save(f'{DIR}/new_img.jpg')

# %%
#recursively remove all .png images

# %%
for file in glob.glob(r'F:' + '**/*.jpg', recursive=True):
  # print the path name of selected files
    print(os.path.join(r'F:', file))
