# %% [markdown]
# # Modeling - First Pass

# %% [markdown]
# ### Installs, Packages, Seeds

# %%
# %pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: efficientnet_pytorch in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (0.7.1)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from efficientnet_pytorch) (1.10.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from torch->efficientnet_pytorch) (4.0.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch
# %pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (1.10.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from torch) (4.0.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# python libraties
import os
import cv2
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import seaborn as sns
from itertools import combinations, product

# import imblearn
import logging
from tqdm import tqdm
from glob import glob
from PIL import Image
import ipywidgets

# pytorch libraries
import torch
from torch import optim,nn
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset
from torchvision import models,transforms
from efficientnet_pytorch import EfficientNet

# sklearn libraries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# google drive
# from google.colab import drive # Connect colab to google drive

# custom modeling libraries
from build_model2 import initialize_model, load_split_data, build_loader, evaluate, train_model, model_scores, eval_model, add_results

# other
import importlib

# %%
import build_model2
importlib.reload(build_model2)

from build_model2 import initialize_model, load_split_data, build_loader, evaluate, train_model, model_scores, eval_model, add_results

# import matplotlib as mpl
# print(mpl.get_cachedir())

# %% [markdown]
# ## Grid Components

# %%
epoch_search = [5, 10, 15, 20]
optim_search = ['SGD', 'Adam', 'AdamW']
model_search = ['resnet', 'vgg', 'efficientnet']
prods = list(product(epoch_search, optim_search, model_search))

es = pd.Series(list(zip(*prods))[0], name = 'epochs', dtype = 'int')
optims = pd.Series(list(zip(*prods))[1], name = 'optimizer')
mods = pd.Series(list(zip(*prods))[2], name = 'pretrained_model')

g_search = pd.concat([es, optims, mods], axis = 1)

# %% [markdown]
# ## Parameters

# %%
model_dict = {'pretrained_model': None, 
              'epochs': None, # NEEDS UPDATE
              'home_directory': '/home/ec2-user/SageMaker/teledermatologyAI_capstone',
              'mod_directory': '/home/ec2-user/SageMaker/teledermatologyAI_capstone/model/gridsearch2',
              'csv_name': 'full_data_rename',
              'split': 'split_3',
              'cl': 'label_0',
              'dev_state': False,
              'dev_sample': 15000,
              'seed': 99,
              'lr': .0035,                  # from prior gridsearch
              'batch_size':64,
              'num_workers':24,
              'transform':3,
              'results_file':'gridsearch_results',
              'model':None, # NEEDS UPDATE
              'device': torch.device('cuda:0'), # NEEDS UPDATE
              'optimizer': None, # NEEDS UPDATE
              'criterion': None, # NEEDS UPDATE
              'tuned_model_name': None, # NEEDS UPDATE
              'show_val_cm': False,
             }

np.random.seed(model_dict['seed'])
torch.cuda.manual_seed(model_dict['seed'])

# Check GPU
print('GPU Type:', torch.cuda.get_device_name())
print('GPU Count:', torch.cuda.device_count())

HOME = model_dict['home_directory']
# Out:
# GPU Type: Tesla T4
# GPU Count: 1

# %%
cd $HOME
# Out:
# /home/ec2-user/SageMaker/teledermatologyAI_capstone

# %% [markdown]
# ## Data

# %%
data, train, test, val = load_split_data(directory = model_dict['home_directory'],
                                         csv_name = model_dict['csv_name'], 
                                         data_split = model_dict['split'], 
                                         label = model_dict['cl'],
                                         mode = 'all',
                                         dev_state = model_dict['dev_state'], 
                                         dev_sample = model_dict['dev_sample'], 
                                         seed = model_dict['seed']
                                         )

# %%
# Label dictionary for evaluation
labels_idx = np.sort(data.label_idx.unique())
label_map = data[['label', 'label_idx']].drop_duplicates().sort_values('label_idx')
label_dict = dict(zip(label_map.label_idx, label_map['label']))
model_dict['label_dict'] = label_dict

# %% [markdown]
# ## In for loop

# %%
g_search = g_search[2:]

# %%
g_search = g_search[g_search['pretrained_model'] != 'efficientnet'][2:]

# %%
# g_search

# %%
# Gridsearch

for i in g_search.iterrows():
    
    # extract gridsearch features
    model_dict['epochs'] = i[1]['epochs']
    model_dict['pretrained_model'] = i[1]['pretrained_model']
    model_dict['optimizer_name'] = i[1]['optimizer']
    me = i[1]['epochs']
    mn = i[1]['pretrained_model']
    mo = i[1]['optimizer']
    model_dict['alias'] = i[0]
    model_dict['tuned_model_name'] = f'{mn}_{me}e_{mo}_GS{i[0]}'
    direc = model_dict['mod_directory']
    nam = model_dict['tuned_model_name']
    
    # set batch size
    if model_dict['pretrained_model'] == 'efficientnet':
        model_dict['batch_size'] = 3
    else: 
        model_dict['batch_size'] = 64
    
    # Load each model
    model_ft, input_size = initialize_model(model_name = model_dict['pretrained_model'], 
                                            num_classes = len(data.label.unique()),
                                            feature_extract = False, 
                                            use_pretrained=True)
    
    # Move model to GPU
    model = model_ft.to(model_dict['device'])
    
    model_dict.update({
                       'model':model,
                       'criterion': nn.CrossEntropyLoss().to(model_dict['device']),
    })
    
    # Define optimizer options:
    if model_dict['optimizer_name'] == 'SGD':
        model_dict.update({'optimizer': optim.SGD(model.parameters(), lr=model_dict['lr'])})
    elif model_dict['optimizer_name'] == 'Adam':
        model_dict.update({'optimizer': optim.Adam(model.parameters(), lr=model_dict['lr'])})
    elif model_dict['optimizer_name'] == 'AdamW':
        model_dict.update({'optimizer': optim.AdamW(model.parameters(), lr=model_dict['lr'])})
    
    # Update dictionary
    model_dict['resize'] = int(input_size/.85)

    
    # Set Transforms
    transform_header = [
                        transforms.Resize(model_dict['resize']), #255
                        transforms.CenterCrop(input_size)
                        ]

    transform_body = [
                      transforms.RandomHorizontalFlip(), # a
                      transforms.RandomVerticalFlip(), # b
                      transforms.RandomRotation(20), # c
                      transforms.RandomCrop(size=(input_size,input_size)), # d
#                       transforms.RandomInvert(), transforms.RandomPosterize(bits=2), # e
#                       transforms.RandomAdjustSharpness(sharpness_factor=2), # f
#                       transforms.RandomSolarize(threshold=192.0), # g
#                       transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1) # h
                      ]

    transform_footer = [transforms.ToTensor(), 
                      transforms.Normalize(mean=[.541, .414, .382], std=[.256,.215,.209])]
    
    val_transform = transforms.Compose([
                                      transforms.Resize(model_dict['resize']),
                                      transforms.CenterCrop(input_size),
                                      transforms.ToTensor(), 
                                      transforms.Normalize(mean=[.541, .414, .382], std=[.256,.215,.209])
                                    ])
    
    test_loader = build_loader(mode = 'test', df = test, transform = val_transform, batch_size = model_dict['batch_size'], num_workers = model_dict['num_workers'])
    val_loader = build_loader(mode = 'val', df = val, transform = val_transform, batch_size = model_dict['batch_size'], num_workers = model_dict['num_workers'])   
    
    transform_list = transform_header + transform_body + transform_footer
    train_transform = transforms.Compose(transform_list)
    train_loader = build_loader(mode = 'train', df = train, transform = train_transform, batch_size = model_dict['batch_size'], num_workers = model_dict['num_workers'])


    loaders = {'train_loader':train_loader,
                            'val_loader': val_loader,
                            'test_loader': test_loader}
    model_dict['loader'] = loaders

    pred_df, val_scores, tot_time = train_model(model_dict = model_dict)

    acc, f1, f2, f5, prec, rec, d_0, d_1, d_2, d_3, d_4 = val_scores
    

    pred_df.to_pickle(f'{direc}/{nam}_preds.pkl')
    
    col_dict = {
#              'model': pd.Series(dtype = 'int'),
#              'file': pd.Series(dtype = 'str'),
             'tuned_model': model_dict['tuned_model_name'],
             'transform': model_dict['transform'],
             'lr': model_dict['lr'],
             'pretrained_model': model_dict['pretrained_model'],
             'optimizer': model_dict['optimizer_name'],
             'epochs': model_dict['epochs'],
#              'num_classes': model_dict['num_classes'],
             'batch_size': model_dict['batch_size'],
             'workers': model_dict['num_workers'],
             'train_time': tot_time,
             'data_split': model_dict['split'],
             'label_set': model_dict['cl'],
             'accur': acc,
             'F1': f1,
             'F0.5': f5,
             'F2': f2,
             'benign_accur': d_0,
             'noncancerous_accur': d_1,
             'malignant_accur': d_2,
             'infection_accur': d_3,
             'unclassified_accur': d_4
    }
    
#     print(tdf.iloc[:i[0]+1][['transform', 'lr', 'accur']])
    add_results(model_dict['results_file'], direc, pd.DataFrame(col_dict, index = [i[0]]))
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
# Out:
# Starting Training resnet_5e_AdamW_GS6
# [epoch 1], [iter 100 of 211],[train loss 1.55903], [train acc 0.33234]
# [epoch 1], [iter 200 of 211],[train loss 1.45048], [train acc 0.36797]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.35239], [val acc 0.41328]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 1], [val loss 1.35239], [val acc 0.41328]
# *****************************************************
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [epoch 2], [iter 100 of 211],[train loss 1.27439], [train acc 0.44344]
# [epoch 2], [iter 200 of 211],[train loss 1.25140], [train acc 0.45414]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.94949], [val acc 0.33285]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 24s
# best record: [epoch 2], [val loss 1.94949], [val acc 0.33285]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 1.19784], [train acc 0.48531]
# [epoch 3], [iter 200 of 211],[train loss 1.19362], [train acc 0.48180]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.21186], [val acc 0.49225]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 28s
# best record: [epoch 3], [val loss 1.21186], [val acc 0.49225]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.15941], [train acc 0.49031]
# [epoch 4], [iter 200 of 211],[train loss 1.15261], [train acc 0.49594]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.61686], [val acc 0.45531]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 28s
# best record: [epoch 4], [val loss 1.61686], [val acc 0.45531]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.13901], [train acc 0.49875]
# [epoch 5], [iter 200 of 211],[train loss 1.11928], [train acc 0.51422]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.17539], [val acc 0.50182]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 29s
# best record: [epoch 5], [val loss 1.17539], [val acc 0.50182]
# *****************************************************
#
# Total run Complete in 12m 7s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training vgg_5e_AdamW_GS7
# [epoch 1], [iter 100 of 211],[train loss 2.01850], [train acc 0.19281]
# [epoch 1], [iter 200 of 211],[train loss 1.82094], [train acc 0.20000]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.61100], [val acc 0.19695]
# ------------------------------------------------------------
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# EPOCH 1 :
# *****************************************************
# Complete in 2m 15s
# best record: [epoch 1], [val loss 1.61100], [val acc 0.19695]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.60602], [train acc 0.21813]
# [epoch 2], [iter 200 of 211],[train loss 1.55547], [train acc 0.25000]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.71549], [val acc 0.19404]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 14s
# best record: [epoch 2], [val loss 1.71549], [val acc 0.19404]
# *****************************************************
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [epoch 3], [iter 100 of 211],[train loss 1.44054], [train acc 0.34063]
# [epoch 3], [iter 200 of 211],[train loss 1.42591], [train acc 0.35445]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.52776], [val acc 0.30560]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 17s
# best record: [epoch 3], [val loss 1.52776], [val acc 0.30560]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.37145], [train acc 0.39578]
# [epoch 4], [iter 200 of 211],[train loss 1.35000], [train acc 0.40328]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.53244], [val acc 0.32049]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 4], [val loss 1.53244], [val acc 0.32049]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.28867], [train acc 0.43938]
# [epoch 5], [iter 200 of 211],[train loss 1.28862], [train acc 0.43750]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.42291], [val acc 0.35283]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 5], [val loss 1.42291], [val acc 0.35283]
# *****************************************************
#
# Total run Complete in 11m 23s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training resnet_10e_SGD_GS9
# [epoch 1], [iter 100 of 211],[train loss 1.31550], [train acc 0.47375]
# [epoch 1], [iter 200 of 211],[train loss 1.19661], [train acc 0.52133]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.04128], [val acc 0.58345]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 24s
# best record: [epoch 1], [val loss 1.04128], [val acc 0.58345]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 0.98613], [train acc 0.60734]
# [epoch 2], [iter 200 of 211],[train loss 0.97286], [train acc 0.61195]
# ------------------------------------------------------------
# [epoch 2], [val loss 0.97778], [val acc 0.61519]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 2], [val loss 0.97778], [val acc 0.61519]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 0.93717], [train acc 0.62953]
# [epoch 3], [iter 200 of 211],[train loss 0.91149], [train acc 0.64000]
# ------------------------------------------------------------
# [epoch 3], [val loss 0.93974], [val acc 0.62888]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 21s
# best record: [epoch 3], [val loss 0.93974], [val acc 0.62888]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 0.85695], [train acc 0.66297]
# [epoch 4], [iter 200 of 211],[train loss 0.86506], [train acc 0.65898]
# ------------------------------------------------------------
# [epoch 4], [val loss 0.92199], [val acc 0.64305]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 28s
# best record: [epoch 4], [val loss 0.92199], [val acc 0.64305]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 0.82976], [train acc 0.67219]
# [epoch 5], [iter 200 of 211],[train loss 0.83092], [train acc 0.67523]
# ------------------------------------------------------------
# [epoch 5], [val loss 0.89462], [val acc 0.65480]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 27s
# best record: [epoch 5], [val loss 0.89462], [val acc 0.65480]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 0.81359], [train acc 0.68359]
# [epoch 6], [iter 200 of 211],[train loss 0.80519], [train acc 0.68648]
# ------------------------------------------------------------
# [epoch 6], [val loss 0.86868], [val acc 0.66655]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 6], [val loss 0.86868], [val acc 0.66655]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 0.78254], [train acc 0.69578]
# [epoch 7], [iter 200 of 211],[train loss 0.77193], [train acc 0.70109]
# ------------------------------------------------------------
# [epoch 7], [val loss 0.86184], [val acc 0.66982]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 21s
# best record: [epoch 7], [val loss 0.86184], [val acc 0.66982]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 0.74778], [train acc 0.71094]
# [epoch 8], [iter 200 of 211],[train loss 0.74531], [train acc 0.71125]
# ------------------------------------------------------------
# [epoch 8], [val loss 0.84643], [val acc 0.67054]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 26s
# best record: [epoch 8], [val loss 0.84643], [val acc 0.67054]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 0.72301], [train acc 0.72156]
# [epoch 9], [iter 200 of 211],[train loss 0.72258], [train acc 0.72219]
# ------------------------------------------------------------
# [epoch 9], [val loss 0.83603], [val acc 0.67430]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 29s
# best record: [epoch 9], [val loss 0.83603], [val acc 0.67430]
# *****************************************************
# [epoch 10], [iter 100 of 211],[train loss 0.70823], [train acc 0.72500]
# [epoch 10], [iter 200 of 211],[train loss 0.69872], [train acc 0.73039]
# ------------------------------------------------------------
# [epoch 10], [val loss 0.83591], [val acc 0.68047]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 10], [val loss 0.83591], [val acc 0.68047]
# *****************************************************
#
# Total run Complete in 23m 52s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training vgg_10e_SGD_GS10
# [epoch 1], [iter 100 of 211],[train loss 1.32087], [train acc 0.43359]
# [epoch 1], [iter 200 of 211],[train loss 1.21237], [train acc 0.49039]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.05983], [val acc 0.57582]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 1s
# best record: [epoch 1], [val loss 1.05983], [val acc 0.57582]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.01420], [train acc 0.59281]
# [epoch 2], [iter 200 of 211],[train loss 1.00266], [train acc 0.59211]
# ------------------------------------------------------------
# [epoch 2], [val loss 0.98194], [val acc 0.60538]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 6s
# best record: [epoch 2], [val loss 0.98194], [val acc 0.60538]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 0.93214], [train acc 0.62453]
# [epoch 3], [iter 200 of 211],[train loss 0.94475], [train acc 0.61938]
# ------------------------------------------------------------
# [epoch 3], [val loss 0.93777], [val acc 0.63517]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 5s
# best record: [epoch 3], [val loss 0.93777], [val acc 0.63517]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 0.92206], [train acc 0.63359]
# [epoch 4], [iter 200 of 211],[train loss 0.90705], [train acc 0.63961]
# ------------------------------------------------------------
# [epoch 4], [val loss 0.91635], [val acc 0.64135]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 4s
# best record: [epoch 4], [val loss 0.91635], [val acc 0.64135]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 0.88037], [train acc 0.64703]
# [epoch 5], [iter 200 of 211],[train loss 0.87141], [train acc 0.65094]
# ------------------------------------------------------------
# [epoch 5], [val loss 0.89400], [val acc 0.65007]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 9s
# best record: [epoch 5], [val loss 0.89400], [val acc 0.65007]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 0.86773], [train acc 0.65781]
# [epoch 6], [iter 200 of 211],[train loss 0.85637], [train acc 0.66195]
# ------------------------------------------------------------
# [epoch 6], [val loss 0.87811], [val acc 0.65262]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 10s
# best record: [epoch 6], [val loss 0.87811], [val acc 0.65262]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 0.84278], [train acc 0.66375]
# [epoch 7], [iter 200 of 211],[train loss 0.82901], [train acc 0.67461]
# ------------------------------------------------------------
# [epoch 7], [val loss 0.86616], [val acc 0.65807]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 12s
# best record: [epoch 7], [val loss 0.86616], [val acc 0.65807]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 0.81783], [train acc 0.68109]
# [epoch 8], [iter 200 of 211],[train loss 0.81297], [train acc 0.68234]
# ------------------------------------------------------------
# [epoch 8], [val loss 0.85571], [val acc 0.66352]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 13s
# best record: [epoch 8], [val loss 0.85571], [val acc 0.66352]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 0.79141], [train acc 0.69016]
# [epoch 9], [iter 200 of 211],[train loss 0.79183], [train acc 0.69008]
# ------------------------------------------------------------
# [epoch 9], [val loss 0.84178], [val acc 0.67478]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 12s
# best record: [epoch 9], [val loss 0.84178], [val acc 0.67478]
# *****************************************************
# [epoch 10], [iter 100 of 211],[train loss 0.77785], [train acc 0.70031]
# [epoch 10], [iter 200 of 211],[train loss 0.78014], [train acc 0.69523]
# ------------------------------------------------------------
# [epoch 10], [val loss 0.83258], [val acc 0.67333]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 7s
# best record: [epoch 10], [val loss 0.83258], [val acc 0.67333]
# *****************************************************
#
# Total run Complete in 21m 20s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training resnet_10e_Adam_GS12
# [epoch 1], [iter 100 of 211],[train loss 1.64978], [train acc 0.30297]
# [epoch 1], [iter 200 of 211],[train loss 1.49588], [train acc 0.36031]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.48423], [val acc 0.31541]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 22s
# best record: [epoch 1], [val loss 1.48423], [val acc 0.31541]
# *****************************************************
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [epoch 2], [iter 100 of 211],[train loss 1.28354], [train acc 0.42125]
# [epoch 2], [iter 200 of 211],[train loss 1.27574], [train acc 0.43242]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.34138], [val acc 0.43193]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 16s
# best record: [epoch 2], [val loss 1.34138], [val acc 0.43193]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 1.21286], [train acc 0.46563]
# [epoch 3], [iter 200 of 211],[train loss 1.20861], [train acc 0.46844]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.31471], [val acc 0.44041]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 20s
# best record: [epoch 3], [val loss 1.31471], [val acc 0.44041]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.18649], [train acc 0.47266]
# [epoch 4], [iter 200 of 211],[train loss 1.17237], [train acc 0.48359]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.23134], [val acc 0.46984]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 26s
# best record: [epoch 4], [val loss 1.23134], [val acc 0.46984]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.13386], [train acc 0.50406]
# [epoch 5], [iter 200 of 211],[train loss 1.13009], [train acc 0.50875]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.38385], [val acc 0.46500]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 27s
# best record: [epoch 5], [val loss 1.38385], [val acc 0.46500]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 1.11015], [train acc 0.51766]
# [epoch 6], [iter 200 of 211],[train loss 1.10460], [train acc 0.52148]
# ------------------------------------------------------------
# [epoch 6], [val loss 1.31166], [val acc 0.48123]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 27s
# best record: [epoch 6], [val loss 1.31166], [val acc 0.48123]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 1.08546], [train acc 0.53547]
# [epoch 7], [iter 200 of 211],[train loss 1.09417], [train acc 0.52906]
# ------------------------------------------------------------
# [epoch 7], [val loss 1.18855], [val acc 0.50279]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 7], [val loss 1.18855], [val acc 0.50279]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 1.06979], [train acc 0.54641]
# [epoch 8], [iter 200 of 211],[train loss 1.06905], [train acc 0.54594]
# ------------------------------------------------------------
# [epoch 8], [val loss 1.25159], [val acc 0.47989]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 17s
# best record: [epoch 8], [val loss 1.25159], [val acc 0.47989]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 1.08980], [train acc 0.53703]
# [epoch 9], [iter 200 of 211],[train loss 1.08708], [train acc 0.54047]
# ------------------------------------------------------------
# [epoch 9], [val loss 1.19358], [val acc 0.51986]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 21s
# best record: [epoch 9], [val loss 1.19358], [val acc 0.51986]
# *****************************************************
# [epoch 10], [iter 100 of 211],[train loss 1.06220], [train acc 0.55312]
# [epoch 10], [iter 200 of 211],[train loss 1.05871], [train acc 0.55453]
# ------------------------------------------------------------
# [epoch 10], [val loss 1.10524], [val acc 0.54300]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 10], [val loss 1.10524], [val acc 0.54300]
# *****************************************************
#
# Total run Complete in 23m 32s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training vgg_10e_Adam_GS13
# [epoch 1], [iter 100 of 211],[train loss 1.78148], [train acc 0.26047]
# [epoch 1], [iter 200 of 211],[train loss 1.61113], [train acc 0.29938]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.73535], [val acc 0.19586]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 6s
# best record: [epoch 1], [val loss 1.73535], [val acc 0.19586]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.39734], [train acc 0.37609]
# [epoch 2], [iter 200 of 211],[train loss 1.38374], [train acc 0.38320]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.59071], [val acc 0.27907]
# ------------------------------------------------------------
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# EPOCH 2 :
# *****************************************************
# Complete in 2m 12s
# best record: [epoch 2], [val loss 1.59071], [val acc 0.27907]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 1.34045], [train acc 0.40719]
# [epoch 3], [iter 200 of 211],[train loss 1.42088], [train acc 0.39422]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.46370], [val acc 0.32280]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 16s
# best record: [epoch 3], [val loss 1.46370], [val acc 0.32280]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.37896], [train acc 0.39313]
# [epoch 4], [iter 200 of 211],[train loss 1.34662], [train acc 0.40773]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.36895], [val acc 0.40746]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 14s
# best record: [epoch 4], [val loss 1.36895], [val acc 0.40746]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.29937], [train acc 0.42938]
# [epoch 5], [iter 200 of 211],[train loss 1.28833], [train acc 0.43297]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.35964], [val acc 0.38953]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 5s
# best record: [epoch 5], [val loss 1.35964], [val acc 0.38953]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 1.25961], [train acc 0.44172]
# [epoch 6], [iter 200 of 211],[train loss 1.24390], [train acc 0.44664]
# ------------------------------------------------------------
# [epoch 6], [val loss 2.82734], [val acc 0.32703]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 7s
# best record: [epoch 6], [val loss 2.82734], [val acc 0.32703]
# *****************************************************
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [epoch 7], [iter 100 of 211],[train loss 1.26656], [train acc 0.44562]
# [epoch 7], [iter 200 of 211],[train loss 1.24687], [train acc 0.44953]
# ------------------------------------------------------------
# [epoch 7], [val loss 1.19757], [val acc 0.45712]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 11s
# best record: [epoch 7], [val loss 1.19757], [val acc 0.45712]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 1.20752], [train acc 0.46891]
# [epoch 8], [iter 200 of 211],[train loss 1.21399], [train acc 0.46266]
# ------------------------------------------------------------
# [epoch 8], [val loss 1.28722], [val acc 0.42188]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 10s
# best record: [epoch 8], [val loss 1.28722], [val acc 0.42188]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 1.27520], [train acc 0.43109]
# [epoch 9], [iter 200 of 211],[train loss 1.24251], [train acc 0.44414]
# ------------------------------------------------------------
# [epoch 9], [val loss 1.26472], [val acc 0.43605]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 15s
# best record: [epoch 9], [val loss 1.26472], [val acc 0.43605]
# *****************************************************
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [epoch 10], [iter 100 of 211],[train loss 1.19317], [train acc 0.46156]
# [epoch 10], [iter 200 of 211],[train loss 1.18935], [train acc 0.46352]
# ------------------------------------------------------------
# [epoch 10], [val loss 1.20383], [val acc 0.45349]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 12s
# best record: [epoch 10], [val loss 1.20383], [val acc 0.45349]
# *****************************************************
#
# Total run Complete in 21m 49s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training resnet_10e_AdamW_GS15
# [epoch 1], [iter 100 of 211],[train loss 1.49528], [train acc 0.33734]
# [epoch 1], [iter 200 of 211],[train loss 1.43453], [train acc 0.36891]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.36429], [val acc 0.41994]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 1], [val loss 1.36429], [val acc 0.41994]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.26281], [train acc 0.44812]
# [epoch 2], [iter 200 of 211],[train loss 1.25510], [train acc 0.44711]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.29874], [val acc 0.42539]
# ------------------------------------------------------------
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# EPOCH 2 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 2], [val loss 1.29874], [val acc 0.42539]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 1.19617], [train acc 0.46375]
# [epoch 3], [iter 200 of 211],[train loss 1.18115], [train acc 0.47477]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.17967], [val acc 0.47699]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 25s
# best record: [epoch 3], [val loss 1.17967], [val acc 0.47699]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.14296], [train acc 0.49938]
# [epoch 4], [iter 200 of 211],[train loss 1.13370], [train acc 0.50133]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.15163], [val acc 0.50206]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 27s
# best record: [epoch 4], [val loss 1.15163], [val acc 0.50206]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.12292], [train acc 0.51234]
# [epoch 5], [iter 200 of 211],[train loss 1.11487], [train acc 0.51000]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.15048], [val acc 0.49358]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 28s
# best record: [epoch 5], [val loss 1.15048], [val acc 0.49358]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 1.11007], [train acc 0.52141]
# [epoch 6], [iter 200 of 211],[train loss 1.10671], [train acc 0.51977]
# ------------------------------------------------------------
# [epoch 6], [val loss 1.11198], [val acc 0.52289]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 6], [val loss 1.11198], [val acc 0.52289]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 1.09492], [train acc 0.52484]
# [epoch 7], [iter 200 of 211],[train loss 1.08899], [train acc 0.53000]
# ------------------------------------------------------------
# [epoch 7], [val loss 1.22217], [val acc 0.48983]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 7], [val loss 1.22217], [val acc 0.48983]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 1.06514], [train acc 0.55516]
# [epoch 8], [iter 200 of 211],[train loss 1.07506], [train acc 0.54703]
# ------------------------------------------------------------
# [epoch 8], [val loss 1.11840], [val acc 0.52641]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 8], [val loss 1.11840], [val acc 0.52641]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 1.04605], [train acc 0.56250]
# [epoch 9], [iter 200 of 211],[train loss 1.06111], [train acc 0.54898]
# ------------------------------------------------------------
# [epoch 9], [val loss 1.09980], [val acc 0.54627]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 9], [val loss 1.09980], [val acc 0.54627]
# *****************************************************
# [epoch 10], [iter 100 of 211],[train loss 1.05443], [train acc 0.55266]
# [epoch 10], [iter 200 of 211],[train loss 1.05865], [train acc 0.55203]
# ------------------------------------------------------------
# [epoch 10], [val loss 1.27410], [val acc 0.46827]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 23s
# best record: [epoch 10], [val loss 1.27410], [val acc 0.46827]
# *****************************************************
#
# Total run Complete in 23m 33s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training vgg_10e_AdamW_GS16
# [epoch 1], [iter 100 of 211],[train loss 1.69132], [train acc 0.26734]
# [epoch 1], [iter 200 of 211],[train loss 1.58968], [train acc 0.29594]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.47482], [val acc 0.31359]
# ------------------------------------------------------------
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# EPOCH 1 :
# *****************************************************
# Complete in 2m 8s
# best record: [epoch 1], [val loss 1.47482], [val acc 0.31359]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.37540], [train acc 0.39109]
# [epoch 2], [iter 200 of 211],[train loss 1.34092], [train acc 0.40914]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.29970], [val acc 0.44767]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 12s
# best record: [epoch 2], [val loss 1.29970], [val acc 0.44767]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 1.22797], [train acc 0.47141]
# [epoch 3], [iter 200 of 211],[train loss 1.21467], [train acc 0.47031]
# ------------------------------------------------------------
# [epoch 3], [val loss 1.28035], [val acc 0.44331]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 11s
# best record: [epoch 3], [val loss 1.28035], [val acc 0.44331]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 1.21668], [train acc 0.46359]
# [epoch 4], [iter 200 of 211],[train loss 1.19516], [train acc 0.47383]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.17475], [val acc 0.50036]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 15s
# best record: [epoch 4], [val loss 1.17475], [val acc 0.50036]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 1.17419], [train acc 0.49547]
# [epoch 5], [iter 200 of 211],[train loss 1.16033], [train acc 0.49609]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.22929], [val acc 0.48292]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 7s
# best record: [epoch 5], [val loss 1.22929], [val acc 0.48292]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 1.13110], [train acc 0.51313]
# [epoch 6], [iter 200 of 211],[train loss 1.12966], [train acc 0.51383]
# ------------------------------------------------------------
# [epoch 6], [val loss 1.16245], [val acc 0.50739]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 14s
# best record: [epoch 6], [val loss 1.16245], [val acc 0.50739]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 1.10937], [train acc 0.52766]
# [epoch 7], [iter 200 of 211],[train loss 1.12043], [train acc 0.51938]
# ------------------------------------------------------------
# [epoch 7], [val loss 1.14547], [val acc 0.49952]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 13s
# best record: [epoch 7], [val loss 1.14547], [val acc 0.49952]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 1.13186], [train acc 0.50438]
# [epoch 8], [iter 200 of 211],[train loss 1.13251], [train acc 0.50789]
# ------------------------------------------------------------
# [epoch 8], [val loss 1.15436], [val acc 0.49976]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 13s
# best record: [epoch 8], [val loss 1.15436], [val acc 0.49976]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 1.10381], [train acc 0.53047]
# [epoch 9], [iter 200 of 211],[train loss 1.11925], [train acc 0.51633]
# ------------------------------------------------------------
# [epoch 9], [val loss 1.15324], [val acc 0.50388]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 13s
# best record: [epoch 9], [val loss 1.15324], [val acc 0.50388]
# *****************************************************
# [epoch 10], [iter 100 of 211],[train loss 1.11121], [train acc 0.52000]
# [epoch 10], [iter 200 of 211],[train loss 1.10859], [train acc 0.52352]
# ------------------------------------------------------------
# [epoch 10], [val loss 1.12763], [val acc 0.51853]
# ------------------------------------------------------------
#
# EPOCH 10 :
# *****************************************************
# Complete in 2m 14s
# best record: [epoch 10], [val loss 1.12763], [val acc 0.51853]
# *****************************************************
#
# Total run Complete in 22m 0s
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Starting Training resnet_15e_SGD_GS18
# [epoch 1], [iter 100 of 211],[train loss 1.30321], [train acc 0.47625]
# [epoch 1], [iter 200 of 211],[train loss 1.18959], [train acc 0.52563]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.04580], [val acc 0.57667]
# ------------------------------------------------------------
#
# EPOCH 1 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 1], [val loss 1.04580], [val acc 0.57667]
# *****************************************************
# [epoch 2], [iter 100 of 211],[train loss 1.00175], [train acc 0.59297]
# [epoch 2], [iter 200 of 211],[train loss 0.97654], [train acc 0.60984]
# ------------------------------------------------------------
# [epoch 2], [val loss 0.97917], [val acc 0.60586]
# ------------------------------------------------------------
#
# EPOCH 2 :
# *****************************************************
# Complete in 2m 20s
# best record: [epoch 2], [val loss 0.97917], [val acc 0.60586]
# *****************************************************
# [epoch 3], [iter 100 of 211],[train loss 0.93035], [train acc 0.62906]
# [epoch 3], [iter 200 of 211],[train loss 0.91166], [train acc 0.63789]
# ------------------------------------------------------------
# [epoch 3], [val loss 0.95466], [val acc 0.62149]
# ------------------------------------------------------------
#
# EPOCH 3 :
# *****************************************************
# Complete in 2m 21s
# best record: [epoch 3], [val loss 0.95466], [val acc 0.62149]
# *****************************************************
# [epoch 4], [iter 100 of 211],[train loss 0.88379], [train acc 0.65125]
# [epoch 4], [iter 200 of 211],[train loss 0.86682], [train acc 0.65781]
# ------------------------------------------------------------
# [epoch 4], [val loss 0.91334], [val acc 0.64595]
# ------------------------------------------------------------
#
# EPOCH 4 :
# *****************************************************
# Complete in 2m 16s
# best record: [epoch 4], [val loss 0.91334], [val acc 0.64595]
# *****************************************************
# [epoch 5], [iter 100 of 211],[train loss 0.84640], [train acc 0.66891]
# [epoch 5], [iter 200 of 211],[train loss 0.83825], [train acc 0.67180]
# ------------------------------------------------------------
# [epoch 5], [val loss 0.89421], [val acc 0.65395]
# ------------------------------------------------------------
#
# EPOCH 5 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 5], [val loss 0.89421], [val acc 0.65395]
# *****************************************************
# [epoch 6], [iter 100 of 211],[train loss 0.79820], [train acc 0.68609]
# [epoch 6], [iter 200 of 211],[train loss 0.80507], [train acc 0.68445]
# ------------------------------------------------------------
# [epoch 6], [val loss 0.88295], [val acc 0.66085]
# ------------------------------------------------------------
#
# EPOCH 6 :
# *****************************************************
# Complete in 2m 22s
# best record: [epoch 6], [val loss 0.88295], [val acc 0.66085]
# *****************************************************
# [epoch 7], [iter 100 of 211],[train loss 0.78467], [train acc 0.69688]
# [epoch 7], [iter 200 of 211],[train loss 0.77986], [train acc 0.69672]
# ------------------------------------------------------------
# [epoch 7], [val loss 0.85735], [val acc 0.66994]
# ------------------------------------------------------------
#
# EPOCH 7 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 7], [val loss 0.85735], [val acc 0.66994]
# *****************************************************
# [epoch 8], [iter 100 of 211],[train loss 0.74984], [train acc 0.71766]
# [epoch 8], [iter 200 of 211],[train loss 0.75177], [train acc 0.71227]
# ------------------------------------------------------------
# [epoch 8], [val loss 0.84853], [val acc 0.67260]
# ------------------------------------------------------------
#
# EPOCH 8 :
# *****************************************************
# Complete in 2m 18s
# best record: [epoch 8], [val loss 0.84853], [val acc 0.67260]
# *****************************************************
# [epoch 9], [iter 100 of 211],[train loss 0.72393], [train acc 0.72047]
# [epoch 9], [iter 200 of 211],[train loss 0.73150], [train acc 0.71578]
# ------------------------------------------------------------
# [epoch 9], [val loss 0.83488], [val acc 0.67648]
# ------------------------------------------------------------
#
# EPOCH 9 :
# *****************************************************
# Complete in 2m 19s
# best record: [epoch 9], [val loss 0.83488], [val acc 0.67648]
# *****************************************************

# %%
2+2
